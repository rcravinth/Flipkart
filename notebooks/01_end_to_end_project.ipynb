# %% [markdown]
# # Flipkart Customer Service Satisfaction — End-to-End
# Run the project pipeline after placing the CSV in `data/flipkart_customer_service.csv`.

# %%
from src.eda import run_eda
run_eda()

# %%
from src.train import main
main()

# %%
from src.explain import export_feature_importance
export_feature_importance()

# %%
import pandas as pd
pd.read_csv('reports/model_metrics.csv')
